# %% [markdown]
# # 🐍 Python для початківців: Типи даних та змінні
# ---
# Цей ноутбук допоможе вам потренуватись у створенні змінних, роботі з базовими типами даних та написанні простих програм у Python.
# Виконуйте завдання послідовно у своїх комірках і звертайте увагу на результати.

# %% [markdown]
# ## Розділ 1. Знайомство зі змінними
# **Мета:** навчитися створювати змінні, присвоювати значення та переглядати типи.
#
# **Завдання 1.** Створи змінні:
# - name — твоє ім’я
# - age — твій вік
# - city — місто, у якому ти живеш
#
# Потім виведи їх на екран.

# %%
name = "Svitlana"
age = int(50)
city = "Borgsdorf"

# %% [markdown]
# **Завдання 2.**
# Додай рядок:

# %%
print("Мене звати", name, "мені", age, "років, я живу в", city)
# Out:
# Мене звати Svitlana мені 50 років, я живу в Borgsdorf

# %% [markdown]
# **Завдання 3.** Використай функцію `type()` для кожної змінної та подивись, який у неї тип.

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(city)
# Out:
# str

# %% [markdown]
# **Завдання 4.**
# Зміни значення змінної age на нове (наприклад, `age = age + 1`) і виведи нове речення:
# “Наступного року мені буде ... років.”

# %%
age = age + 1

# %%
print(age)
# Out:
# 51

# %% [markdown]
# ## Розділ 2. Основні типи даних
# **Мета:** попрактикуватись із `int`, `float`, `str`, `bool`.
#
# **Завдання 5.**
#
# Створи змінні:
# - a = 10
# - b = 3.5
# - c = "Python"

# %%
a = 10
b = 3.5
c = "Python"

# %% [markdown]
# **Завдання 6.**
#
# Виконай такі дії та подивись, який буде результат:
# - a + b
# - a / 2
# - a // 2
# - a % 3
# - a ** 3

# %%
a + b
# Out:
# 13.5

# %%
a / 2
# Out:
# 5.0

# %%
a // 2
# Out:
# 5

# %%
a % 3
# Out:
# 1

# %%
a ** 3
# Out:
# 1000

# %% [markdown]
# **Завдання 7.**
# Зміни тип змінної `a` на `str` і об’єднай її з `c`.

# %%
a = str(a)
a+c
# Out:
# '10Python'

# %% [markdown]
# **Завдання 8.**
# Порівняй різні значення:
# - 5 > 2
# - 7 == 8
# - 10 != 10
# - 3 <= 5

# %%
5 > 2
# Out:
# True

# %%
7 == 8
# Out:
# False

# %%
10 !=10
# Out:
# False

# %%
3 <= 5
# Out:
# True

# %% [markdown]
# ## Розділ 3. Робота з рядками (`str`)

# %% [markdown]
# **Завдання 9.**
# Створи рядок `text = "Python is fun!"`.

# %%
text = "Python is fun!"

# %% [markdown]
# **Завдання 10.**
#
# Виведи:
# - довжину рядка (len(text))
# - перший і останній символ
# - рядок у верхньому регістрі
# - рядок у нижньому регістрі

# %%
print(len(text))
# Out:
# 14

# %%
print(text[0])
# Out:
# P

# %%
text.upper()
# Out:
# 'PYTHON IS FUN!'

# %%
print(text[-1])
# Out:
# !

# %%
text.lower()
# Out:
# 'python is fun!'

# %% [markdown]
# **Завдання 11.**
# Створи речення з кількох змінних:
# ```
# lang = "Python"
# level = "beginner"
# print(f"I am a {level} in {lang}")
# ```

# %%
lang = "Python"
level = "beginner"
print(f"I am a {level} in {lang}")
# Out:
# I am a beginner in Python

# %% [markdown]
# **Завдання 12.**
# Попроси користувача ввести своє ім’я через input() і виведи:
# `print("Привіт,", name + "!")`

# %%
name = input("Enter your name: ")
print("Привіт,", name, "!")
# Out:
# Enter your name:  Svitlana
# Привіт, Svitlana !

# %% [markdown]
# ## Розділ 4. Робота з числами

# %% [markdown]
# **Завдання 13.**
# Обчисли площу прямокутника:
# - створи змінні `a = 5, b = 8`
# - знайди `area = a * b`
# - виведи результат: "Площа прямокутника дорівнює ..."

# %%
a = 5
b = 8
area = a * b
print(f"Площа прямокутника дорівнює {area}")
# Out:
# Площа прямокутника дорівнює 40

# %% [markdown]
# **Завдання 14.**
# Обчисли середнє арифметичне трьох чисел, введених користувачем.

# %%
num1 = int(input("Enter a number1: "))
num2 = int(input("Enter a number2: "))
num3 = int(input("Enter a number3: "))
print(f"Cереднє арифметичне трьох чисел {num1}, {num2} та {num3} дорівнює", int((num1 + num2 + num3) // 3))
# Out:
# Enter a number1:  2
# Enter a number2:  3
# Enter a number3:  4
# Cереднє арифметичне трьох чисел 2, 3 та 4 дорівнює 3

# %% [markdown]
# **Завдання 15.**
# Створи змінну `temperature_c = 25` і переведи її у Фаренгейти:
#
# `temperature_f = temperature_c * 9/5 + 32`

# %%
temperature_c = 25
temperature_f = temperature_c * 9/5 + 32
print("Температура у Фаренгейтах становить", temperature_f)
# Out:
# Температура у Фаренгейтах становить 77.0

# %% [markdown]
# ## Розділ 5. Логічні вирази (`bool`)

# %% [markdown]
# **Завдання 16.**
# Перевір, чи людина повнолітня:
# ```
# age = int(input("Скільки тобі років? "))
# is_adult = age >= 18
# print("Повнолітній?", is_adult)

# %%
age = int(input("Скільки тобі років? "))
is_adult = age >= 18
print("Повнолітній?", is_adult)
# Out:
# Скільки тобі років?  50
# Повнолітній? True

# %% [markdown]
# **Завдання 17.**
# Напиши перевірку парності:
# ```
# number = int(input("Введи число: "))
# print("Парне?", number % 2 == 0)

# %%
number = int(input("Введи число: "))
print("Парне?", number % 2 == 0)
# Out:
# Введи число:  5
# Парне? False

# %% [markdown]
# **Завдання 18.**
# Створи дві змінні x = 10, y = 20.
# Виведи результат:
# - `x > 5 and y < 30`
# - `x < 0 or y == 20`
# - `not(x > y)`

# %%
x, y = 10, 20
print(x > 5 and y < 30)
print(x < 0 or y == 20)
print(not(x > y))
# Out:
# True
# True
# True

# %% [markdown]
# ## Розділ 6. Комбіновані завдання

# %% [markdown]
# **Завдання 19.**
# Попроси користувача ввести рік народження та обчисли вік.
# Потім виведи:
# ```
# "Твій вік: ... років"
# "Повнолітній? True/False"

# %%
date_of__birth = input("Enter a year of birth: ")
age = 2025 - int(date_of__birth)
print(f"Твій вік: {age} років")
is_adult = age >= 18
print("Повнолітній?", is_adult)
# Out:
# Enter a year of birth:  1974
# Твій вік: 51 років
# Повнолітній? True

# %% [markdown]
# **Завдання 20.**
# Створи калькулятор, який:
# - запитує два числа і дію (+, -, *, /)
# - виводить результат обчислення.

# %%
n1 = float(input("Enter n1: "))
n2 = float(input("Enter n2: "))
op = input("Enter op: (+, - , *, /) ")
if op == "+":
   result = n1 + n2
if op == "-":
    result = n1 - n2
if op == "*":
    result = n1 * n2
if op == "/":
    result = n1 / n2
print(result)
# Out:
# Enter n1:  3
# Enter n2:  5
# Enter op: (+, - , *, /)  -
# -2.0

# %% [markdown]
# **Завдання 21.**
# Створи просту програму для обчислення індексу маси тіла (BMI):
# ```
# weight = float(input("Введи вагу (кг): "))
# height = float(input("Введи зріст (м): "))
# bmi = weight / (height ** 2)
# print("Твій індекс маси тіла:", bmi)

# %%
weight = float(input("Введи вагу (кг): "))
height = float(input("Введи зріст (м): "))
bmi = weight / (height ** 2)
print(f"Твій індекс маси тіла: {bmi}")
# Out:
# Введи вагу (кг):  56
# Введи зріст (м):  163
# Твій індекс маси тіла: 0.0021077195227520796

# %% [markdown]
# **Завдання 22.**
# Створи змінну `sentence = "learning python is easy and fun"`
#
# 1. перетвори першу літеру у велику `(capitalize())`
# 2. порахуй, скільки разів зустрічається літера "a"
# 3. перевір, чи рядок містить слово "fun"

# %%
sentence = "learning python is easy and fun"
print(sentence.capitalize())
print(sentence.count("a"))
print(sentence.find("fun"))
# Out:
# Learning python is easy and fun
# 3
# 28

# %% [markdown]
# **Завдання 23.**
# 🧮 Конвертер валют
# Попроси користувача ввести суму в євро та курс долара.
# Обчисли, скільки це буде в доларах.

# %%
currency_euro = int(input("Enter a sum of euro: "))
course_dollar = float(input("Enter a course of dollar: "))
currency_dollar = (currency_euro) * (course_dollar)
print(currency_euro, "євро становить", currency_dollar, "доларів по курсу", course_dollar)
# Out:
# Enter a sum of euro:  20
# Enter a course of dollar:  1.16
# 20 євро становить 23.2 доларів по курсу 1.16

# %% [markdown]
# **Завдання 24.**
# 📆 Калькулятор віку
# Введи поточний рік і рік народження користувача.
# Порахуйте, скільки років людині буде через 5 років.

# %%
year_now = int(input("Enter a current year: "))
date_birth = int(input("Enter your date of birth: "))
age_now = year_now - date_birth
age_in_5 = age_now + 5
print("Через 5 років Вам буде", age_in_5, "років")
# Out:
# Enter a current year:  2025
# Enter your date of birth:  1974
# Через 5 років Вам буде 56 років

# %% [markdown]
# **Завдання 25.**
# Користувач вводить:
# - ім’я
# - улюблену мову програмування
#
# Якщо це "Python" — вивести "Ти крутий!",
# інакше — "Треба спробувати Python:)"

# %%
name = input("Enter your name: ")
lang = input("Enter your favourite computer language: ")
if lang == "Python":
    print("Ти крутий!")
else:
    print("Треба спробувати Python:)")
# Out:
# Enter your name:  Svitlana
# Enter your favourite computer language:  SQL
# Треба спробувати Python:)
